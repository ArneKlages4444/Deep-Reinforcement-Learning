# %%
# !pip3 uninstall gym
# Out:
# Found existing installation: gym 0.25.1
# Uninstalling gym-0.25.1:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/gym-0.25.1.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/gym/*
# Proceed (y/n)? y
#   Successfully uninstalled gym-0.25.1

# %%
# !pip3 install gym[mujoco]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gym[mujoco]
#   Downloading gym-0.25.2.tar.gz (734 kB)
#      |████████████████████████████████| 734 kB 7.1 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym[mujoco]) (1.5.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /usr/local/lib/python3.7/dist-packages (from gym[mujoco]) (4.12.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.7/dist-packages (from gym[mujoco]) (1.21.6)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.7/dist-packages (from gym[mujoco]) (0.0.8)
# Collecting mujoco==2.2.0
#   Downloading mujoco-2.2.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 57.5 MB/s
# Collecting imageio>=2.14.1
#   Downloading imageio-2.21.1-py3-none-any.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 40.1 MB/s
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from mujoco==2.2.0->gym[mujoco]) (1.2.0)
# Collecting glfw
#   Downloading glfw-2.5.4-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38-none-manylinux2014_x86_64.whl (207 kB)
#      |████████████████████████████████| 207 kB 57.0 MB/s
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.7/dist-packages (from mujoco==2.2.0->gym[mujoco]) (3.1.6)
# Collecting pillow>=8.3.2
#   Downloading Pillow-9.2.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 42.1 MB/s
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.8.0->gym[mujoco]) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.8.0->gym[mujoco]) (3.8.1)
# Building wheels for collected packages: gym
#   Building wheel for gym (PEP 517) ... done
#   Created wheel for gym: filename=gym-0.25.2-py3-none-any.whl size=852317 sha256=957a13ef4709bc932d5942c88dc03a6c4cc34f47becedfacdfed58da298b7d31
#   Stored in directory: /root/.cache/pip/wheels/3a/a8/81/4ba83fc99a5637e27f4e16da10f9e15ff61f77ce524d23a8d7
# Successfully built gym
# Installing collected packages: pillow, glfw, mujoco, imageio, gym
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: imageio
#     Found existing installation: imageio 2.9.0
#     Uninstalling imageio-2.9.0:
#       Successfully uninstalled imageio-2.9.0
# Successfully installed glfw-2.5.4 gym-0.25.2 imageio-2.21.1 mujoco-2.2.0 pillow-9.2.0

# %%
# !pip3 install pybullet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pybullet
#   Downloading pybullet-3.2.5-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (91.7 MB)
#      |████████████████████████████████| 91.7 MB 28 kB/s
# Installing collected packages: pybullet
# Successfully installed pybullet-3.2.5

# %%
import tensorflow as tf
import numpy as np


class EpisodeBuffer:

    def __init__(self, gamma):
        self._gamma = gamma
        self._state_memory = []
        self._action_memory = []
        self.reward_memory = []

    def add(self, state, action, reward):
        self._state_memory.append(tf.convert_to_tensor(state, dtype=tf.float32))
        self._action_memory.append(tf.convert_to_tensor(action, dtype=tf.float32))
        self.reward_memory.append(tf.convert_to_tensor(reward, dtype=tf.float32))

    def get_as_data_set(self, batch_size=1):
        # TODO: better implementation for discounting (cumsum, tf.scan)
        g = np.zeros_like(self.reward_memory, dtype=np.float32)
        for t in range(len(self.reward_memory)):
            g_sum = 0
            gamma_t = 1
            for k in range(t, len(self.reward_memory)):
                g_sum += self.reward_memory[k] * gamma_t  # r_n[k].numpy()
                gamma_t *= self._gamma
            g[t] = g_sum
        # g = (g - np.mean(g)) / (np.std(g) + 1e-10) # normalize g?
        index = tf.range(len(self._state_memory), dtype=tf.float32)
        return tf.data.Dataset.from_tensor_slices(
            (self._state_memory, self._action_memory, self.reward_memory, g, index)).batch(batch_size)


import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense


def create_policy_network(learning_rate, state_dim=4, action_dim=1):
    inputs = keras.Input(shape=state_dim)
    x = Dense(256, activation=tf.nn.relu)(inputs)
    x = Dense(256, activation=tf.nn.relu)(x)
    mu = Dense(action_dim, activation=None)(x)  # TODO: better activation sigmoid?
    # TODO: better activation, sigmoid or tf.clip_by_value(sigma, 1e-6, 1)?
    sigma = Dense(action_dim, activation=tf.nn.softplus)(x)
    model = keras.Model(inputs=inputs, outputs=(mu, sigma))
    model.compile(optimizer=Adam(learning_rate=learning_rate))
    return model


# from EpisodeBuffer import EpisodeBuffer
import tensorflow as tf
from tensorflow import math as tfm
from tensorflow_probability import distributions as tfd
import numpy as np
import pybullet_envs


class Agent:

    def __init__(self, environment, policy_network_generator, learning_rate=0.0003, gamma=0.99):
        self._environment = environment
        self._gamma = gamma
        self._policy_network = policy_network_generator(learning_rate)

    def learn(self, episode):  # TODO: check dimensions
        with tf.GradientTape() as tape:
            loss = 0
            for state, action, _, g, i in episode:
                prob_of_action = self.log_probs_of_action_in_state_form_policy(state, action)
                loss += -(tfm.pow(self._gamma, i[0]) * g * prob_of_action)  # TODO: tfm.pow(self.gamma, i) necessary?
        gradients = tape.gradient(loss, self._policy_network.trainable_variables)
        self._policy_network.optimizer.apply_gradients(zip(gradients, self._policy_network.trainable_variables))

    def distribution_of_policy_in_state(self, state):
        mu, sigma = self._policy_network(state)
        # TODO: MultivariateNormalDiag(loc=mus, scale_diag=sigmas) better?
        distribution = tfd.Normal(mu, sigma)
        return distribution

    def log_probs_of_action_in_state_form_policy(self, state, action):
        distribution = self.distribution_of_policy_in_state(state)
        log_probs = distribution.log_prob(action)
        return log_probs

    def sample_actions_form_policy(self, state):
        distribution = self.distribution_of_policy_in_state(state)
        actions = distribution.sample()
        return actions

    def act_deterministic(self, state):
        actions_prime, _ = self._policy_network(tf.convert_to_tensor([state], dtype=tf.float32))
        return self._act(actions_prime)

    def act_stochastic(self, state):
        actions_prime = self.sample_actions_form_policy(tf.convert_to_tensor([state], dtype=tf.float32))
        return self._act(actions_prime)

    def _act(self, actions):
        observation_prime, reward, done, _ = self._environment.step(actions[0])
        return actions, observation_prime, reward, done

    def sample_to_episode_buffer(self):
        buffer = EpisodeBuffer(self._gamma)
        observation = self._environment.reset()
        done = 0
        ret = 0
        while not done:
            action, observation_prime, reward, done = self.act_stochastic(observation)
            ret += reward
            buffer.add(observation, action, reward)
            observation = observation_prime
        return buffer, ret

    def train(self, epochs):
        print("start training!")
        rets = []
        for e in range(epochs):
            buffer, ret = self.sample_to_episode_buffer()
            rets.append(ret)
            print("epoch:", e, "return:", ret, "avg return:", np.average(rets[-50:]))
            episode = buffer.get_as_data_set()
            self.learn(episode)
        print("training finished!")


from functools import partial
import gym
import tensorflow as tf
# import pybullet_envs

# from Networks.InvertedPendulumNetwork import create_policy_network
# from ReinforceAgent import Agent

if __name__ == '__main__':
    tf.keras.backend.clear_session()
    env = gym.make("InvertedPendulum-v4")
    #env = gym.make('InvertedPendulumBulletEnv-v0')
    print("state_dim=", env.observation_space.shape, "action_dim=", env.action_space.shape[0], "action_scaling:",
          env.action_space.high)

    agent = Agent(environment=env,
                  policy_network_generator=partial(create_policy_network, state_dim=env.observation_space.shape[0],
                                                   action_dim=env.action_space.shape[0]))
    agent.train(2000)
# Out:
# state_dim= (4,) action_dim= 1 action_scaling: [3.]
# start training!
# epoch: 0 return: 8.0 avg return: 8.0
# epoch: 1 return: 9.0 avg return: 8.5
# epoch: 2 return: 6.0 avg return: 7.666666666666667
# epoch: 3 return: 5.0 avg return: 7.0
# epoch: 4 return: 5.0 avg return: 6.6
# epoch: 5 return: 8.0 avg return: 6.833333333333333
# epoch: 6 return: 5.0 avg return: 6.571428571428571
# epoch: 7 return: 8.0 avg return: 6.75
# epoch: 8 return: 11.0 avg return: 7.222222222222222
# epoch: 9 return: 10.0 avg return: 7.5
# epoch: 10 return: 7.0 avg return: 7.454545454545454
# epoch: 11 return: 7.0 avg return: 7.416666666666667
# epoch: 12 return: 8.0 avg return: 7.461538461538462
# epoch: 13 return: 11.0 avg return: 7.714285714285714
# epoch: 14 return: 9.0 avg return: 7.8
# epoch: 15 return: 17.0 avg return: 8.375
# epoch: 16 return: 10.0 avg return: 8.470588235294118
# epoch: 17 return: 7.0 avg return: 8.38888888888889
# epoch: 18 return: 17.0 avg return: 8.842105263157896
# epoch: 19 return: 11.0 avg return: 8.95
# epoch: 20 return: 6.0 avg return: 8.80952380952381
# epoch: 21 return: 11.0 avg return: 8.909090909090908
# epoch: 22 return: 22.0 avg return: 9.478260869565217
# epoch: 23 return: 8.0 avg return: 9.416666666666666
# epoch: 24 return: 12.0 avg return: 9.52
# epoch: 25 return: 7.0 avg return: 9.423076923076923
# epoch: 26 return: 6.0 avg return: 9.296296296296296
# epoch: 27 return: 10.0 avg return: 9.321428571428571
# epoch: 28 return: 11.0 avg return: 9.379310344827585
# epoch: 29 return: 12.0 avg return: 9.466666666666667
# epoch: 30 return: 13.0 avg return: 9.580645161290322
# epoch: 31 return: 11.0 avg return: 9.625
# epoch: 32 return: 5.0 avg return: 9.484848484848484
# epoch: 33 return: 18.0 avg return: 9.735294117647058
# epoch: 34 return: 17.0 avg return: 9.942857142857143
# epoch: 35 return: 10.0 avg return: 9.944444444444445
# epoch: 36 return: 12.0 avg return: 10.0
# epoch: 37 return: 12.0 avg return: 10.052631578947368
# epoch: 38 return: 10.0 avg return: 10.051282051282051
# epoch: 39 return: 24.0 avg return: 10.4
# epoch: 40 return: 14.0 avg return: 10.487804878048781
# epoch: 41 return: 40.0 avg return: 11.19047619047619
# epoch: 42 return: 5.0 avg return: 11.046511627906977
# epoch: 43 return: 14.0 avg return: 11.113636363636363
# epoch: 44 return: 30.0 avg return: 11.533333333333333
# epoch: 45 return: 8.0 avg return: 11.456521739130435
# epoch: 46 return: 8.0 avg return: 11.382978723404255
# epoch: 47 return: 16.0 avg return: 11.479166666666666
# epoch: 48 return: 10.0 avg return: 11.448979591836734
# epoch: 49 return: 7.0 avg return: 11.36
# epoch: 50 return: 9.0 avg return: 11.38
# epoch: 51 return: 12.0 avg return: 11.44
# epoch: 52 return: 17.0 avg return: 11.66
# epoch: 53 return: 6.0 avg return: 11.68
# epoch: 54 return: 19.0 avg return: 11.96
# epoch: 55 return: 15.0 avg return: 12.1
# epoch: 56 return: 11.0 avg return: 12.22
# epoch: 57 return: 26.0 avg return: 12.58
# epoch: 58 return: 13.0 avg return: 12.62
# epoch: 59 return: 18.0 avg return: 12.78
# epoch: 60 return: 18.0 avg return: 13.0
# epoch: 61 return: 22.0 avg return: 13.3
# epoch: 62 return: 14.0 avg return: 13.42
# epoch: 63 return: 9.0 avg return: 13.38
# epoch: 64 return: 18.0 avg return: 13.56
# epoch: 65 return: 42.0 avg return: 14.06
# epoch: 66 return: 29.0 avg return: 14.44
# epoch: 67 return: 12.0 avg return: 14.54
# epoch: 68 return: 12.0 avg return: 14.44
# epoch: 69 return: 38.0 avg return: 14.98
# epoch: 70 return: 11.0 avg return: 15.08
# epoch: 71 return: 66.0 avg return: 16.18
# epoch: 72 return: 48.0 avg return: 16.7
# epoch: 73 return: 46.0 avg return: 17.46
# epoch: 74 return: 9.0 avg return: 17.4
# epoch: 75 return: 25.0 avg return: 17.76
# epoch: 76 return: 12.0 avg return: 17.88
# epoch: 77 return: 30.0 avg return: 18.28
# epoch: 78 return: 33.0 avg return: 18.72
# epoch: 79 return: 21.0 avg return: 18.9
# epoch: 80 return: 30.0 avg return: 19.24
# epoch: 81 return: 13.0 avg return: 19.28
# epoch: 82 return: 22.0 avg return: 19.62
# epoch: 83 return: 38.0 avg return: 20.02
# epoch: 84 return: 10.0 avg return: 19.88
# epoch: 85 return: 35.0 avg return: 20.38
# epoch: 86 return: 17.0 avg return: 20.48
# epoch: 87 return: 15.0 avg return: 20.54
# epoch: 88 return: 65.0 avg return: 21.64
# epoch: 89 return: 20.0 avg return: 21.56
# epoch: 90 return: 22.0 avg return: 21.72
# epoch: 91 return: 18.0 avg return: 21.28
# epoch: 92 return: 23.0 avg return: 21.64
# epoch: 93 return: 21.0 avg return: 21.78
# epoch: 94 return: 22.0 avg return: 21.62
# epoch: 95 return: 34.0 avg return: 22.14
# epoch: 96 return: 20.0 avg return: 22.38
# epoch: 97 return: 25.0 avg return: 22.56
# epoch: 98 return: 8.0 avg return: 22.52
# epoch: 99 return: 17.0 avg return: 22.72
# epoch: 100 return: 24.0 avg return: 23.02
# epoch: 101 return: 44.0 avg return: 23.66
# epoch: 102 return: 25.0 avg return: 23.82
# epoch: 103 return: 25.0 avg return: 24.2
# epoch: 104 return: 32.0 avg return: 24.46
# epoch: 105 return: 10.0 avg return: 24.36
# epoch: 106 return: 15.0 avg return: 24.44
# epoch: 107 return: 30.0 avg return: 24.52
# epoch: 108 return: 109.0 avg return: 26.44
# epoch: 109 return: 17.0 avg return: 26.42
# epoch: 110 return: 34.0 avg return: 26.74
# epoch: 111 return: 35.0 avg return: 27.0
# epoch: 112 return: 13.0 avg return: 26.98
# epoch: 113 return: 15.0 avg return: 27.1
# epoch: 114 return: 37.0 avg return: 27.48
# epoch: 115 return: 36.0 avg return: 27.36
# epoch: 116 return: 62.0 avg return: 28.02
# epoch: 117 return: 70.0 avg return: 29.18
# epoch: 118 return: 39.0 avg return: 29.72
# epoch: 119 return: 34.0 avg return: 29.64
# epoch: 120 return: 50.0 avg return: 30.42
# epoch: 121 return: 36.0 avg return: 29.82
# epoch: 122 return: 51.0 avg return: 29.88
# epoch: 123 return: 34.0 avg return: 29.64
# epoch: 124 return: 46.0 avg return: 30.38
# epoch: 125 return: 64.0 avg return: 31.16
# epoch: 126 return: 32.0 avg return: 31.56
# epoch: 127 return: 25.0 avg return: 31.46
# epoch: 128 return: 43.0 avg return: 31.66
# epoch: 129 return: 12.0 avg return: 31.48
# epoch: 130 return: 34.0 avg return: 31.56
# epoch: 131 return: 30.0 avg return: 31.9
# epoch: 132 return: 38.0 avg return: 32.22
# epoch: 133 return: 39.0 avg return: 32.24
# epoch: 134 return: 56.0 avg return: 33.16
# epoch: 135 return: 40.0 avg return: 33.26
# epoch: 136 return: 61.0 avg return: 34.14
# epoch: 137 return: 12.0 avg return: 34.08
# epoch: 138 return: 27.0 avg return: 33.32
# epoch: 139 return: 48.0 avg return: 33.88
# epoch: 140 return: 43.0 avg return: 34.3
# epoch: 141 return: 75.0 avg return: 35.44
# epoch: 142 return: 15.0 avg return: 35.28
# epoch: 143 return: 42.0 avg return: 35.7
# epoch: 144 return: 75.0 avg return: 36.76
# epoch: 145 return: 24.0 avg return: 36.56
# epoch: 146 return: 59.0 avg return: 37.34
# epoch: 147 return: 39.0 avg return: 37.62
# epoch: 148 return: 78.0 avg return: 39.02
# epoch: 149 return: 27.0 avg return: 39.22
# epoch: 150 return: 13.0 avg return: 39.0
# epoch: 151 return: 43.0 avg return: 38.98
# epoch: 152 return: 71.0 avg return: 39.9
# epoch: 153 return: 38.0 avg return: 40.16
# epoch: 154 return: 55.0 avg return: 40.62
# epoch: 155 return: 35.0 avg return: 41.12
# epoch: 156 return: 60.0 avg return: 42.02
# epoch: 157 return: 17.0 avg return: 41.76
# epoch: 158 return: 41.0 avg return: 40.4
# epoch: 159 return: 38.0 avg return: 40.82
# epoch: 160 return: 78.0 avg return: 41.7
# epoch: 161 return: 46.0 avg return: 41.92
# epoch: 162 return: 36.0 avg return: 42.38
# epoch: 163 return: 40.0 avg return: 42.88
# epoch: 164 return: 31.0 avg return: 42.76
# epoch: 165 return: 76.0 avg return: 43.56
# epoch: 166 return: 67.0 avg return: 43.66
# epoch: 167 return: 19.0 avg return: 42.64
# epoch: 168 return: 70.0 avg return: 43.26
# epoch: 169 return: 53.0 avg return: 43.64
# epoch: 170 return: 45.0 avg return: 43.54
# epoch: 171 return: 39.0 avg return: 43.6
# epoch: 172 return: 41.0 avg return: 43.4
# epoch: 173 return: 76.0 avg return: 44.24
# epoch: 174 return: 97.0 avg return: 45.26
# epoch: 175 return: 66.0 avg return: 45.3
# epoch: 176 return: 96.0 avg return: 46.58
# epoch: 177 return: 80.0 avg return: 47.68
# epoch: 178 return: 105.0 avg return: 48.92
# epoch: 179 return: 31.0 avg return: 49.3
# epoch: 180 return: 105.0 avg return: 50.72
# epoch: 181 return: 55.0 avg return: 51.22
# epoch: 182 return: 67.0 avg return: 51.8
# epoch: 183 return: 121.0 avg return: 53.44
# epoch: 184 return: 67.0 avg return: 53.66
# epoch: 185 return: 62.0 avg return: 54.1
# epoch: 186 return: 44.0 avg return: 53.76
# epoch: 187 return: 183.0 avg return: 57.18
# epoch: 188 return: 34.0 avg return: 57.32
# epoch: 189 return: 90.0 avg return: 58.16
# epoch: 190 return: 125.0 avg return: 59.8
# epoch: 191 return: 55.0 avg return: 59.4
# epoch: 192 return: 80.0 avg return: 60.7
# epoch: 193 return: 55.0 avg return: 60.96
# epoch: 194 return: 27.0 avg return: 60.0
# epoch: 195 return: 89.0 avg return: 61.3
# epoch: 196 return: 99.0 avg return: 62.1
# epoch: 197 return: 116.0 avg return: 63.64
# epoch: 198 return: 183.0 avg return: 65.74
# epoch: 199 return: 45.0 avg return: 66.1
# epoch: 200 return: 46.0 avg return: 66.76
# epoch: 201 return: 110.0 avg return: 68.1
# epoch: 202 return: 61.0 avg return: 67.9
# epoch: 203 return: 35.0 avg return: 67.84
# epoch: 204 return: 37.0 avg return: 67.48
# epoch: 205 return: 218.0 avg return: 71.14
# epoch: 206 return: 59.0 avg return: 71.12
# epoch: 207 return: 51.0 avg return: 71.8
# epoch: 208 return: 31.0 avg return: 71.6
# epoch: 209 return: 75.0 avg return: 72.34
# epoch: 210 return: 93.0 avg return: 72.64
# epoch: 211 return: 55.0 avg return: 72.82
# epoch: 212 return: 109.0 avg return: 74.28
# epoch: 213 return: 117.0 avg return: 75.82
# epoch: 214 return: 74.0 avg return: 76.68
# epoch: 215 return: 59.0 avg return: 76.34
# epoch: 216 return: 79.0 avg return: 76.58
# epoch: 217 return: 100.0 avg return: 78.2
# epoch: 218 return: 115.0 avg return: 79.1
# epoch: 219 return: 93.0 avg return: 79.9
# epoch: 220 return: 56.0 avg return: 80.12
# epoch: 221 return: 79.0 avg return: 80.92
# epoch: 222 return: 135.0 avg return: 82.8
# epoch: 223 return: 123.0 avg return: 83.74
# epoch: 224 return: 144.0 avg return: 84.68
# epoch: 225 return: 77.0 avg return: 84.9
# epoch: 226 return: 53.0 avg return: 84.04
# epoch: 227 return: 137.0 avg return: 85.18
# epoch: 228 return: 122.0 avg return: 85.52
# epoch: 229 return: 150.0 avg return: 87.9
# epoch: 230 return: 69.0 avg return: 87.18
# epoch: 231 return: 131.0 avg return: 88.7
# epoch: 232 return: 54.0 avg return: 88.44
# epoch: 233 return: 77.0 avg return: 87.56
# epoch: 234 return: 104.0 avg return: 88.3
# epoch: 235 return: 168.0 avg return: 90.42
# epoch: 236 return: 106.0 avg return: 91.66
# epoch: 237 return: 139.0 avg return: 90.78
# epoch: 238 return: 60.0 avg return: 91.3
# epoch: 239 return: 135.0 avg return: 92.2
# epoch: 240 return: 201.0 avg return: 93.72
# epoch: 241 return: 119.0 avg return: 95.0
# epoch: 242 return: 141.0 avg return: 96.22
# epoch: 243 return: 91.0 avg return: 96.94
# epoch: 244 return: 118.0 avg return: 98.76
# epoch: 245 return: 124.0 avg return: 99.46
# epoch: 246 return: 126.0 avg return: 100.0
# epoch: 247 return: 128.0 avg return: 100.24
# epoch: 248 return: 143.0 avg return: 99.44
# epoch: 249 return: 135.0 avg return: 101.24
# epoch: 250 return: 96.0 avg return: 102.24
# epoch: 251 return: 135.0 avg return: 102.74
# epoch: 252 return: 97.0 avg return: 103.46
# epoch: 253 return: 115.0 avg return: 105.06
# epoch: 254 return: 112.0 avg return: 106.56
# epoch: 255 return: 45.0 avg return: 103.1
# epoch: 256 return: 110.0 avg return: 104.12
# epoch: 257 return: 115.0 avg return: 105.4
# epoch: 258 return: 84.0 avg return: 106.46
# epoch: 259 return: 107.0 avg return: 107.1
# epoch: 260 return: 96.0 avg return: 107.16
# epoch: 261 return: 108.0 avg return: 108.22
# epoch: 262 return: 48.0 avg return: 107.0
# epoch: 263 return: 31.0 avg return: 105.28
# epoch: 264 return: 85.0 avg return: 105.5
# epoch: 265 return: 85.0 avg return: 106.02
# epoch: 266 return: 50.0 avg return: 105.44
# epoch: 267 return: 75.0 avg return: 104.94
# epoch: 268 return: 101.0 avg return: 104.66
# epoch: 269 return: 43.0 avg return: 103.66
# epoch: 270 return: 102.0 avg return: 104.58
# epoch: 271 return: 84.0 avg return: 104.68
# epoch: 272 return: 50.0 avg return: 102.98
# epoch: 273 return: 40.0 avg return: 101.32
# epoch: 274 return: 44.0 avg return: 99.32
# epoch: 275 return: 41.0 avg return: 98.6
# epoch: 276 return: 44.0 avg return: 98.42
# epoch: 277 return: 93.0 avg return: 97.54
# epoch: 278 return: 102.0 avg return: 97.14
# epoch: 279 return: 70.0 avg return: 95.54
# epoch: 280 return: 44.0 avg return: 95.04
# epoch: 281 return: 128.0 avg return: 94.98
# epoch: 282 return: 41.0 avg return: 94.72
# epoch: 283 return: 42.0 avg return: 94.02
# epoch: 284 return: 78.0 avg return: 93.5
# epoch: 285 return: 82.0 avg return: 91.78
# epoch: 286 return: 50.0 avg return: 90.66
# epoch: 287 return: 132.0 avg return: 90.52
# epoch: 288 return: 101.0 avg return: 91.34
# epoch: 289 return: 47.0 avg return: 89.58
# epoch: 290 return: 65.0 avg return: 86.86
# epoch: 291 return: 84.0 avg return: 86.16
# epoch: 292 return: 137.0 avg return: 86.08
# epoch: 293 return: 120.0 avg return: 86.66
# epoch: 294 return: 88.0 avg return: 86.06
# epoch: 295 return: 114.0 avg return: 85.86
# epoch: 296 return: 125.0 avg return: 85.84
# epoch: 297 return: 40.0 avg return: 84.08
# epoch: 298 return: 37.0 avg return: 81.96
# epoch: 299 return: 64.0 avg return: 80.54
# epoch: 300 return: 102.0 avg return: 80.66
# epoch: 301 return: 78.0 avg return: 79.52
# epoch: 302 return: 234.0 avg return: 82.26
# epoch: 303 return: 103.0 avg return: 82.02
# epoch: 304 return: 119.0 avg return: 82.16
# epoch: 305 return: 155.0 avg return: 84.36
# epoch: 306 return: 178.0 avg return: 85.72
# epoch: 307 return: 142.0 avg return: 86.26
# epoch: 308 return: 103.0 avg return: 86.64
# epoch: 309 return: 135.0 avg return: 87.2
# epoch: 310 return: 93.0 avg return: 87.14
# epoch: 311 return: 86.0 avg return: 86.7
# epoch: 312 return: 92.0 avg return: 87.58
# epoch: 313 return: 84.0 avg return: 88.64
# epoch: 314 return: 84.0 avg return: 88.62
# epoch: 315 return: 82.0 avg return: 88.56
# epoch: 316 return: 65.0 avg return: 88.86
# epoch: 317 return: 54.0 avg return: 88.44
# epoch: 318 return: 65.0 avg return: 87.72
# epoch: 319 return: 49.0 avg return: 87.84
# epoch: 320 return: 52.0 avg return: 86.84
# epoch: 321 return: 48.0 avg return: 86.12
# epoch: 322 return: 46.0 avg return: 86.04
# epoch: 323 return: 51.0 avg return: 86.26
# epoch: 324 return: 24.0 avg return: 85.86
# epoch: 325 return: 51.0 avg return: 86.06
# epoch: 326 return: 43.0 avg return: 86.04
# epoch: 327 return: 38.0 avg return: 84.94
# epoch: 328 return: 40.0 avg return: 83.7
# epoch: 329 return: 31.0 avg return: 82.92
# epoch: 330 return: 42.0 avg return: 82.88
# epoch: 331 return: 35.0 avg return: 81.02
# epoch: 332 return: 35.0 avg return: 80.9
# epoch: 333 return: 28.0 avg return: 80.62
# epoch: 334 return: 39.0 avg return: 79.84
# epoch: 335 return: 32.0 avg return: 78.84
# epoch: 336 return: 36.0 avg return: 78.56
# epoch: 337 return: 36.0 avg return: 76.64
# epoch: 338 return: 36.0 avg return: 75.34
# epoch: 339 return: 27.0 avg return: 74.94
# epoch: 340 return: 32.0 avg return: 74.28
# epoch: 341 return: 35.0 avg return: 73.3
# epoch: 342 return: 40.0 avg return: 71.36
# epoch: 343 return: 38.0 avg return: 69.72
# epoch: 344 return: 38.0 avg return: 68.72
# epoch: 345 return: 40.0 avg return: 67.24
# epoch: 346 return: 37.0 avg return: 65.48
# epoch: 347 return: 40.0 avg return: 65.48
# epoch: 348 return: 46.0 avg return: 65.66
# epoch: 349 return: 30.0 avg return: 64.98
# epoch: 350 return: 35.0 avg return: 63.64
# epoch: 351 return: 43.0 avg return: 62.94
# epoch: 352 return: 42.0 avg return: 59.1
# epoch: 353 return: 15.0 avg return: 57.34
# epoch: 354 return: 45.0 avg return: 55.86
# epoch: 355 return: 42.0 avg return: 53.6
# epoch: 356 return: 45.0 avg return: 50.94
# epoch: 357 return: 51.0 avg return: 49.12
# epoch: 358 return: 44.0 avg return: 47.94
# epoch: 359 return: 48.0 avg return: 46.2
# epoch: 360 return: 46.0 avg return: 45.26
# epoch: 361 return: 42.0 avg return: 44.38
# epoch: 362 return: 46.0 avg return: 43.46
# epoch: 363 return: 53.0 avg return: 42.84
# epoch: 364 return: 42.0 avg return: 42.0
# epoch: 365 return: 46.0 avg return: 41.28
# epoch: 366 return: 46.0 avg return: 40.9
# epoch: 367 return: 52.0 avg return: 40.86
# epoch: 368 return: 41.0 avg return: 40.38
# epoch: 369 return: 43.0 avg return: 40.26
# epoch: 370 return: 51.0 avg return: 40.24
# epoch: 371 return: 52.0 avg return: 40.32
# epoch: 372 return: 57.0 avg return: 40.54
# epoch: 373 return: 47.0 avg return: 40.46
# epoch: 374 return: 54.0 avg return: 41.06
# epoch: 375 return: 44.0 avg return: 40.92
# epoch: 376 return: 48.0 avg return: 41.02
# epoch: 377 return: 51.0 avg return: 41.28
# epoch: 378 return: 46.0 avg return: 41.4
# epoch: 379 return: 47.0 avg return: 41.72
# epoch: 380 return: 51.0 avg return: 41.9
# epoch: 381 return: 46.0 avg return: 42.12
# epoch: 382 return: 57.0 avg return: 42.56
# epoch: 383 return: 53.0 avg return: 43.06
# epoch: 384 return: 42.0 avg return: 43.12
# epoch: 385 return: 48.0 avg return: 43.44
# epoch: 386 return: 47.0 avg return: 43.66
# epoch: 387 return: 56.0 avg return: 44.06
# epoch: 388 return: 48.0 avg return: 44.3
# epoch: 389 return: 44.0 avg return: 44.64
# epoch: 390 return: 50.0 avg return: 45.0
# epoch: 391 return: 55.0 avg return: 45.4
# epoch: 392 return: 54.0 avg return: 45.68
# epoch: 393 return: 55.0 avg return: 46.02
# epoch: 394 return: 57.0 avg return: 46.4
# epoch: 395 return: 46.0 avg return: 46.52
# epoch: 396 return: 53.0 avg return: 46.84
# epoch: 397 return: 44.0 avg return: 46.92
# epoch: 398 return: 50.0 avg return: 47.0
# epoch: 399 return: 46.0 avg return: 47.32
# epoch: 400 return: 57.0 avg return: 47.76
# epoch: 401 return: 47.0 avg return: 47.84
# epoch: 402 return: 52.0 avg return: 48.04
# epoch: 403 return: 47.0 avg return: 48.68
# epoch: 404 return: 55.0 avg return: 48.88
# epoch: 405 return: 52.0 avg return: 49.08
# epoch: 406 return: 46.0 avg return: 49.1
# epoch: 407 return: 53.0 avg return: 49.14
# epoch: 408 return: 59.0 avg return: 49.44
# epoch: 409 return: 52.0 avg return: 49.52
# epoch: 410 return: 54.0 avg return: 49.68
# epoch: 411 return: 45.0 avg return: 49.74
# epoch: 412 return: 53.0 avg return: 49.88
# epoch: 413 return: 46.0 avg return: 49.74
# epoch: 414 return: 49.0 avg return: 49.88
# epoch: 415 return: 58.0 avg return: 50.12
# epoch: 416 return: 50.0 avg return: 50.2
# epoch: 417 return: 42.0 avg return: 50.0
# epoch: 418 return: 51.0 avg return: 50.2
# epoch: 419 return: 46.0 avg return: 50.26
# epoch: 420 return: 59.0 avg return: 50.42
# epoch: 421 return: 48.0 avg return: 50.34
# epoch: 422 return: 59.0 avg return: 50.38
# epoch: 423 return: 51.0 avg return: 50.46
# epoch: 424 return: 54.0 avg return: 50.46
# epoch: 425 return: 63.0 avg return: 50.84
# epoch: 426 return: 53.0 avg return: 50.94
# epoch: 427 return: 62.0 avg return: 51.16
# epoch: 428 return: 65.0 avg return: 51.54
# epoch: 429 return: 53.0 avg return: 51.66
# epoch: 430 return: 45.0 avg return: 51.54
# epoch: 431 return: 66.0 avg return: 51.94
# epoch: 432 return: 66.0 avg return: 52.12
# epoch: 433 return: 67.0 avg return: 52.4
# epoch: 434 return: 74.0 avg return: 53.04
# epoch: 435 return: 64.0 avg return: 53.36
# epoch: 436 return: 74.0 avg return: 53.9
# epoch: 437 return: 78.0 avg return: 54.34
# epoch: 438 return: 76.0 avg return: 54.9
# epoch: 439 return: 79.0 avg return: 55.6
# epoch: 440 return: 69.0 avg return: 55.98
# epoch: 441 return: 107.0 avg return: 57.02
# epoch: 442 return: 93.0 avg return: 57.8
# epoch: 443 return: 86.0 avg return: 58.42
# epoch: 444 return: 89.0 avg return: 59.06
# epoch: 445 return: 108.0 avg return: 60.3
# epoch: 446 return: 102.0 avg return: 61.28
# epoch: 447 return: 84.0 avg return: 62.08
# epoch: 448 return: 107.0 avg return: 63.22
# epoch: 449 return: 97.0 avg return: 64.24
# epoch: 450 return: 97.0 avg return: 65.04
# epoch: 451 return: 106.0 avg return: 66.22
# epoch: 452 return: 104.0 avg return: 67.26
# epoch: 453 return: 144.0 avg return: 69.2
# epoch: 454 return: 79.0 avg return: 69.68
# epoch: 455 return: 123.0 avg return: 71.1
# epoch: 456 return: 102.0 avg return: 72.22
# epoch: 457 return: 92.0 avg return: 73.0
# epoch: 458 return: 109.0 avg return: 74.0
# epoch: 459 return: 112.0 avg return: 75.2
# epoch: 460 return: 97.0 avg return: 76.06
# epoch: 461 return: 107.0 avg return: 77.3
# epoch: 462 return: 98.0 avg return: 78.2
# epoch: 463 return: 107.0 avg return: 79.42
# epoch: 464 return: 85.0 avg return: 80.14
# epoch: 465 return: 77.0 avg return: 80.52
# epoch: 466 return: 80.0 avg return: 81.12
# epoch: 467 return: 124.0 avg return: 82.76
# epoch: 468 return: 138.0 avg return: 84.5
# epoch: 469 return: 111.0 avg return: 85.8
# epoch: 470 return: 92.0 avg return: 86.46
# epoch: 471 return: 111.0 avg return: 87.72
# epoch: 472 return: 112.0 avg return: 88.78
# epoch: 473 return: 100.0 avg return: 89.76
# epoch: 474 return: 115.0 avg return: 90.98
# epoch: 475 return: 77.0 avg return: 91.26
# epoch: 476 return: 109.0 avg return: 92.38
# epoch: 477 return: 92.0 avg return: 92.98
# epoch: 478 return: 86.0 avg return: 93.4
# epoch: 479 return: 87.0 avg return: 94.08
# epoch: 480 return: 93.0 avg return: 95.04
# epoch: 481 return: 86.0 avg return: 95.44
# epoch: 482 return: 72.0 avg return: 95.56
# epoch: 483 return: 79.0 avg return: 95.8
# epoch: 484 return: 78.0 avg return: 95.88
# epoch: 485 return: 83.0 avg return: 96.26
# epoch: 486 return: 78.0 avg return: 96.34
# epoch: 487 return: 83.0 avg return: 96.44
# epoch: 488 return: 55.0 avg return: 96.02
# epoch: 489 return: 58.0 avg return: 95.6
# epoch: 490 return: 66.0 avg return: 95.54
# epoch: 491 return: 60.0 avg return: 94.6
# epoch: 492 return: 66.0 avg return: 94.06
# epoch: 493 return: 67.0 avg return: 93.68
# epoch: 494 return: 53.0 avg return: 92.96
# epoch: 495 return: 59.0 avg return: 91.98
# epoch: 496 return: 50.0 avg return: 90.94
# epoch: 497 return: 60.0 avg return: 90.46
# epoch: 498 return: 57.0 avg return: 89.46
# epoch: 499 return: 64.0 avg return: 88.8
# epoch: 500 return: 46.0 avg return: 87.78
# epoch: 501 return: 57.0 avg return: 86.8
# epoch: 502 return: 54.0 avg return: 85.8
# epoch: 503 return: 50.0 avg return: 83.92
# epoch: 504 return: 47.0 avg return: 83.28
# epoch: 505 return: 53.0 avg return: 81.88
# epoch: 506 return: 48.0 avg return: 80.8
# epoch: 507 return: 53.0 avg return: 80.02
# epoch: 508 return: 57.0 avg return: 78.98
# epoch: 509 return: 44.0 avg return: 77.62
# epoch: 510 return: 57.0 avg return: 76.82
# epoch: 511 return: 50.0 avg return: 75.68
# epoch: 512 return: 56.0 avg return: 74.84
# epoch: 513 return: 47.0 avg return: 73.64
# epoch: 514 return: 54.0 avg return: 73.02
# epoch: 515 return: 45.0 avg return: 72.38
# epoch: 516 return: 56.0 avg return: 71.9
# epoch: 517 return: 52.0 avg return: 70.46
# epoch: 518 return: 57.0 avg return: 68.84
# epoch: 519 return: 52.0 avg return: 67.66
# epoch: 520 return: 56.0 avg return: 66.94
# epoch: 521 return: 47.0 avg return: 65.66
# epoch: 522 return: 58.0 avg return: 64.58
# epoch: 523 return: 46.0 avg return: 63.5
# epoch: 524 return: 43.0 avg return: 62.06
# epoch: 525 return: 43.0 avg return: 61.38
# epoch: 526 return: 52.0 avg return: 60.24
# epoch: 527 return: 50.0 avg return: 59.4
# epoch: 528 return: 50.0 avg return: 58.68
# epoch: 529 return: 45.0 avg return: 57.84
# epoch: 530 return: 60.0 avg return: 57.18
# epoch: 531 return: 58.0 avg return: 56.62
# epoch: 532 return: 52.0 avg return: 56.22
# epoch: 533 return: 47.0 avg return: 55.58
# epoch: 534 return: 42.0 avg return: 54.86
# epoch: 535 return: 44.0 avg return: 54.08
# epoch: 536 return: 48.0 avg return: 53.48
# epoch: 537 return: 48.0 avg return: 52.78
# epoch: 538 return: 56.0 avg return: 52.8
# epoch: 539 return: 49.0 avg return: 52.62
# epoch: 540 return: 46.0 avg return: 52.22
# epoch: 541 return: 52.0 avg return: 52.06
# epoch: 542 return: 49.0 avg return: 51.72
# epoch: 543 return: 48.0 avg return: 51.34
# epoch: 544 return: 59.0 avg return: 51.46
# epoch: 545 return: 48.0 avg return: 51.24
# epoch: 546 return: 49.0 avg return: 51.22
# epoch: 547 return: 52.0 avg return: 51.06
# epoch: 548 return: 57.0 avg return: 51.06
# epoch: 549 return: 50.0 avg return: 50.78
# epoch: 550 return: 67.0 avg return: 51.2
# epoch: 551 return: 58.0 avg return: 51.22
# epoch: 552 return: 66.0 avg return: 51.46
# epoch: 553 return: 51.0 avg return: 51.48
# epoch: 554 return: 43.0 avg return: 51.4
# epoch: 555 return: 49.0 avg return: 51.32
# epoch: 556 return: 53.0 avg return: 51.42
# epoch: 557 return: 62.0 avg return: 51.6
# epoch: 558 return: 44.0 avg return: 51.34
# epoch: 559 return: 58.0 avg return: 51.62
# epoch: 560 return: 66.0 avg return: 51.8
# epoch: 561 return: 70.0 avg return: 52.2
# epoch: 562 return: 69.0 avg return: 52.46
# epoch: 563 return: 51.0 avg return: 52.54
# epoch: 564 return: 69.0 avg return: 52.84
# epoch: 565 return: 69.0 avg return: 53.32
# epoch: 566 return: 75.0 avg return: 53.7
# epoch: 567 return: 76.0 avg return: 54.18
# epoch: 568 return: 85.0 avg return: 54.74
# epoch: 569 return: 63.0 avg return: 54.96
# epoch: 570 return: 86.0 avg return: 55.56
# epoch: 571 return: 102.0 avg return: 56.66
# epoch: 572 return: 83.0 avg return: 57.16
# epoch: 573 return: 83.0 avg return: 57.9
# epoch: 574 return: 125.0 avg return: 59.54
# epoch: 575 return: 94.0 avg return: 60.56
# epoch: 576 return: 108.0 avg return: 61.68
# epoch: 577 return: 101.0 avg return: 62.7
# epoch: 578 return: 97.0 avg return: 63.64
# epoch: 579 return: 74.0 avg return: 64.22
# epoch: 580 return: 139.0 avg return: 65.8
# epoch: 581 return: 134.0 avg return: 67.32
# epoch: 582 return: 135.0 avg return: 68.98
# epoch: 583 return: 116.0 avg return: 70.36
# epoch: 584 return: 145.0 avg return: 72.42
# epoch: 585 return: 112.0 avg return: 73.78
# epoch: 586 return: 155.0 avg return: 75.92
# epoch: 587 return: 149.0 avg return: 77.94
# epoch: 588 return: 131.0 avg return: 79.44
# epoch: 589 return: 139.0 avg return: 81.24
# epoch: 590 return: 105.0 avg return: 82.42
# epoch: 591 return: 218.0 avg return: 85.74
# epoch: 592 return: 113.0 avg return: 87.02
# epoch: 593 return: 140.0 avg return: 88.86
# epoch: 594 return: 127.0 avg return: 90.22
# epoch: 595 return: 233.0 avg return: 93.92
# epoch: 596 return: 140.0 avg return: 95.74
# epoch: 597 return: 160.0 avg return: 97.9
# epoch: 598 return: 139.0 avg return: 99.54
# epoch: 599 return: 163.0 avg return: 101.8
# epoch: 600 return: 203.0 avg return: 104.52
# epoch: 601 return: 156.0 avg return: 106.48
# epoch: 602 return: 164.0 avg return: 108.44
# epoch: 603 return: 176.0 avg return: 110.94
# epoch: 604 return: 184.0 avg return: 113.76
# epoch: 605 return: 221.0 avg return: 117.2
# epoch: 606 return: 154.0 avg return: 119.22
# epoch: 607 return: 298.0 avg return: 123.94
# epoch: 608 return: 201.0 avg return: 127.08
# epoch: 609 return: 350.0 avg return: 132.92
# epoch: 610 return: 186.0 avg return: 135.32
# epoch: 611 return: 241.0 avg return: 138.74
# epoch: 612 return: 229.0 avg return: 141.94
# epoch: 613 return: 212.0 avg return: 145.16
# epoch: 614 return: 208.0 avg return: 147.94
# epoch: 615 return: 276.0 avg return: 152.08
# epoch: 616 return: 151.0 avg return: 153.6
# epoch: 617 return: 223.0 avg return: 156.54
# epoch: 618 return: 221.0 avg return: 159.26
# epoch: 619 return: 205.0 avg return: 162.1
# epoch: 620 return: 73.0 avg return: 161.84
# epoch: 621 return: 98.0 avg return: 161.76
# epoch: 622 return: 158.0 avg return: 163.26
# epoch: 623 return: 149.0 avg return: 164.58
# epoch: 624 return: 157.0 avg return: 165.22
# epoch: 625 return: 158.0 avg return: 166.5
# epoch: 626 return: 150.0 avg return: 167.34
# epoch: 627 return: 153.0 avg return: 168.38
# epoch: 628 return: 166.0 avg return: 169.76
# epoch: 629 return: 79.0 avg return: 169.86
# epoch: 630 return: 62.0 avg return: 168.32
# epoch: 631 return: 75.0 avg return: 167.14
# epoch: 632 return: 139.0 avg return: 167.22
# epoch: 633 return: 39.0 avg return: 165.68
# epoch: 634 return: 53.0 avg return: 163.84
# epoch: 635 return: 77.0 avg return: 163.14
# epoch: 636 return: 65.0 avg return: 161.34
# epoch: 637 return: 85.0 avg return: 160.06
# epoch: 638 return: 108.0 avg return: 159.6
# epoch: 639 return: 67.0 avg return: 158.16
# epoch: 640 return: 33.0 avg return: 156.72
# epoch: 641 return: 110.0 avg return: 154.56
# epoch: 642 return: 75.0 avg return: 153.8
# epoch: 643 return: 44.0 avg return: 151.88
# epoch: 644 return: 133.0 avg return: 152.0
# epoch: 645 return: 50.0 avg return: 148.34
# epoch: 646 return: 91.0 avg return: 147.36
# epoch: 647 return: 79.0 avg return: 145.74
# epoch: 648 return: 49.0 avg return: 143.94
# epoch: 649 return: 124.0 avg return: 143.16
# epoch: 650 return: 154.0 avg return: 142.18
# epoch: 651 return: 74.0 avg return: 140.54
# epoch: 652 return: 95.0 avg return: 139.16
# epoch: 653 return: 97.0 avg return: 137.58
# epoch: 654 return: 41.0 avg return: 134.72
# epoch: 655 return: 127.0 avg return: 132.84
# epoch: 656 return: 100.0 avg return: 131.76
# epoch: 657 return: 104.0 avg return: 127.88
# epoch: 658 return: 48.0 avg return: 124.82
# epoch: 659 return: 80.0 avg return: 119.42
# epoch: 660 return: 89.0 avg return: 117.48
# epoch: 661 return: 131.0 avg return: 115.28
# epoch: 662 return: 175.0 avg return: 114.2
# epoch: 663 return: 232.0 avg return: 114.6
# epoch: 664 return: 136.0 avg return: 113.16
# epoch: 665 return: 121.0 avg return: 110.06
# epoch: 666 return: 79.0 avg return: 108.62
# epoch: 667 return: 185.0 avg return: 107.86
# epoch: 668 return: 110.0 avg return: 105.64
# epoch: 669 return: 148.0 avg return: 104.5
# epoch: 670 return: 139.0 avg return: 105.82
# epoch: 671 return: 126.0 avg return: 106.38
# epoch: 672 return: 102.0 avg return: 105.26
# epoch: 673 return: 119.0 avg return: 104.66
# epoch: 674 return: 111.0 avg return: 103.74
# epoch: 675 return: 96.0 avg return: 102.5
# epoch: 676 return: 100.0 avg return: 101.5
# epoch: 677 return: 87.0 avg return: 100.18
# epoch: 678 return: 85.0 avg return: 98.56
# epoch: 679 return: 91.0 avg return: 98.8
# epoch: 680 return: 90.0 avg return: 99.36
# epoch: 681 return: 83.0 avg return: 99.52
# epoch: 682 return: 81.0 avg return: 98.36
# epoch: 683 return: 80.0 avg return: 99.18
# epoch: 684 return: 65.0 avg return: 99.42
# epoch: 685 return: 68.0 avg return: 99.24
# epoch: 686 return: 73.0 avg return: 99.4
# epoch: 687 return: 71.0 avg return: 99.12
# epoch: 688 return: 75.0 avg return: 98.46
# epoch: 689 return: 86.0 avg return: 98.84
# epoch: 690 return: 77.0 avg return: 99.72
# epoch: 691 return: 74.0 avg return: 99.0
# epoch: 692 return: 65.0 avg return: 98.8
# epoch: 693 return: 75.0 avg return: 99.42
# epoch: 694 return: 87.0 avg return: 98.5
# epoch: 695 return: 76.0 avg return: 99.02
# epoch: 696 return: 7.0 avg return: 97.34
# epoch: 697 return: 8.0 avg return: 95.92
# epoch: 698 return: 71.0 avg return: 96.36
# epoch: 699 return: 44.0 avg return: 94.76
# epoch: 700 return: 81.0 avg return: 93.3
# epoch: 701 return: 95.0 avg return: 93.72
# epoch: 702 return: 90.0 avg return: 93.62
# epoch: 703 return: 7.0 avg return: 91.82
# epoch: 704 return: 45.0 avg return: 91.9
# epoch: 705 return: 91.0 avg return: 91.18
# epoch: 706 return: 88.0 avg return: 90.94
# epoch: 707 return: 42.0 avg return: 89.7
# epoch: 708 return: 45.0 avg return: 89.64
# epoch: 709 return: 40.0 avg return: 88.84
# epoch: 710 return: 76.0 avg return: 88.58
# epoch: 711 return: 82.0 avg return: 87.6
# epoch: 712 return: 87.0 avg return: 85.84
# epoch: 713 return: 96.0 avg return: 83.12
# epoch: 714 return: 77.0 avg return: 81.94
# epoch: 715 return: 66.0 avg return: 80.84
# epoch: 716 return: 76.0 avg return: 80.78
# epoch: 717 return: 65.0 avg return: 78.38
# epoch: 718 return: 71.0 avg return: 77.6
# epoch: 719 return: 71.0 avg return: 76.06
# epoch: 720 return: 61.0 avg return: 74.5
# epoch: 721 return: 78.0 avg return: 73.54
# epoch: 722 return: 64.0 avg return: 72.78
# epoch: 723 return: 74.0 avg return: 71.88
# epoch: 724 return: 71.0 avg return: 71.08
# epoch: 725 return: 48.0 avg return: 70.12
# epoch: 726 return: 68.0 avg return: 69.48
# epoch: 727 return: 70.0 avg return: 69.14
# epoch: 728 return: 71.0 avg return: 68.86
# epoch: 729 return: 69.0 avg return: 68.42
# epoch: 730 return: 75.0 avg return: 68.12
# epoch: 731 return: 70.0 avg return: 67.86
# epoch: 732 return: 79.0 avg return: 67.82
# epoch: 733 return: 68.0 avg return: 67.58
# epoch: 734 return: 63.0 avg return: 67.54
# epoch: 735 return: 74.0 avg return: 67.66
# epoch: 736 return: 63.0 avg return: 67.46
# epoch: 737 return: 63.0 avg return: 67.3
# epoch: 738 return: 82.0 avg return: 67.44
# epoch: 739 return: 74.0 avg return: 67.2
# epoch: 740 return: 68.0 avg return: 67.02
# epoch: 741 return: 66.0 avg return: 66.86
# epoch: 742 return: 72.0 avg return: 67.0
# epoch: 743 return: 67.0 avg return: 66.84
# epoch: 744 return: 72.0 avg return: 66.54
# epoch: 745 return: 63.0 avg return: 66.28
# epoch: 746 return: 67.0 avg return: 67.48
# epoch: 747 return: 78.0 avg return: 68.88
# epoch: 748 return: 74.0 avg return: 68.94
# epoch: 749 return: 74.0 avg return: 69.54
# epoch: 750 return: 72.0 avg return: 69.36
# epoch: 751 return: 83.0 avg return: 69.12
# epoch: 752 return: 80.0 avg return: 68.92
# epoch: 753 return: 68.0 avg return: 70.14
# epoch: 754 return: 44.0 avg return: 70.12
# epoch: 755 return: 68.0 avg return: 69.66
# epoch: 756 return: 84.0 avg return: 69.58
# epoch: 757 return: 72.0 avg return: 70.18
# epoch: 758 return: 66.0 avg return: 70.6
# epoch: 759 return: 71.0 avg return: 71.22
# epoch: 760 return: 78.0 avg return: 71.26
# epoch: 761 return: 81.0 avg return: 71.24
# epoch: 762 return: 79.0 avg return: 71.08
# epoch: 763 return: 76.0 avg return: 70.68
# epoch: 764 return: 78.0 avg return: 70.7
# epoch: 765 return: 43.0 avg return: 70.24
# epoch: 766 return: 90.0 avg return: 70.52
# epoch: 767 return: 47.0 avg return: 70.16
# epoch: 768 return: 82.0 avg return: 70.38
# epoch: 769 return: 91.0 avg return: 70.78
# epoch: 770 return: 45.0 avg return: 70.46
# epoch: 771 return: 88.0 avg return: 70.66
# epoch: 772 return: 93.0 avg return: 71.24
# epoch: 773 return: 99.0 avg return: 71.74
# epoch: 774 return: 80.0 avg return: 71.92
# epoch: 775 return: 81.0 avg return: 72.58
# epoch: 776 return: 82.0 avg return: 72.86
# epoch: 777 return: 69.0 avg return: 72.84
# epoch: 778 return: 76.0 avg return: 72.94
# epoch: 779 return: 85.0 avg return: 73.26
# epoch: 780 return: 89.0 avg return: 73.54
# epoch: 781 return: 84.0 avg return: 73.82
# epoch: 782 return: 92.0 avg return: 74.08
# epoch: 783 return: 84.0 avg return: 74.4
# epoch: 784 return: 80.0 avg return: 74.74
# epoch: 785 return: 74.0 avg return: 74.74
# epoch: 786 return: 83.0 avg return: 75.14
# epoch: 787 return: 87.0 avg return: 75.62
# epoch: 788 return: 88.0 avg return: 75.74
# epoch: 789 return: 45.0 avg return: 75.16
# epoch: 790 return: 83.0 avg return: 75.46
# epoch: 791 return: 43.0 avg return: 75.0
# epoch: 792 return: 69.0 avg return: 74.94
# epoch: 793 return: 66.0 avg return: 74.92
# epoch: 794 return: 75.0 avg return: 74.98
# epoch: 795 return: 76.0 avg return: 75.24
# epoch: 796 return: 62.0 avg return: 75.14
# epoch: 797 return: 73.0 avg return: 75.04
# epoch: 798 return: 75.0 avg return: 75.06
# epoch: 799 return: 80.0 avg return: 75.18
# epoch: 800 return: 64.0 avg return: 75.02
# epoch: 801 return: 66.0 avg return: 74.68
# epoch: 802 return: 69.0 avg return: 74.46
# epoch: 803 return: 67.0 avg return: 74.44
# epoch: 804 return: 77.0 avg return: 75.1
# epoch: 805 return: 78.0 avg return: 75.3
# epoch: 806 return: 72.0 avg return: 75.06
# epoch: 807 return: 73.0 avg return: 75.08
# epoch: 808 return: 65.0 avg return: 75.06
# epoch: 809 return: 63.0 avg return: 74.9
# epoch: 810 return: 80.0 avg return: 74.94
# epoch: 811 return: 66.0 avg return: 74.64
# epoch: 812 return: 72.0 avg return: 74.5
# epoch: 813 return: 63.0 avg return: 74.24
# epoch: 814 return: 63.0 avg return: 73.94
# epoch: 815 return: 79.0 avg return: 74.66
# epoch: 816 return: 31.0 avg return: 73.48
# epoch: 817 return: 64.0 avg return: 73.82
# epoch: 818 return: 28.0 avg return: 72.74
# epoch: 819 return: 53.0 avg return: 71.98
# epoch: 820 return: 73.0 avg return: 72.54
# epoch: 821 return: 63.0 avg return: 72.04
# epoch: 822 return: 64.0 avg return: 71.46
# epoch: 823 return: 80.0 avg return: 71.08
# epoch: 824 return: 45.0 avg return: 70.38
# epoch: 825 return: 66.0 avg return: 70.08
# epoch: 826 return: 80.0 avg return: 70.04
# epoch: 827 return: 73.0 avg return: 70.12
# epoch: 828 return: 49.0 avg return: 69.58
# epoch: 829 return: 49.0 avg return: 68.86
# epoch: 830 return: 82.0 avg return: 68.72
# epoch: 831 return: 69.0 avg return: 68.42
# epoch: 832 return: 68.0 avg return: 67.94
# epoch: 833 return: 71.0 avg return: 67.68
# epoch: 834 return: 71.0 avg return: 67.5
# epoch: 835 return: 29.0 avg return: 66.6
# epoch: 836 return: 73.0 avg return: 66.4
# epoch: 837 return: 89.0 avg return: 66.44
# epoch: 838 return: 88.0 avg return: 66.44
# epoch: 839 return: 93.0 avg return: 67.4
# epoch: 840 return: 80.0 avg return: 67.34
# epoch: 841 return: 88.0 avg return: 68.24
# epoch: 842 return: 80.0 avg return: 68.46
# epoch: 843 return: 87.0 avg return: 68.88
# epoch: 844 return: 43.0 avg return: 68.24
# epoch: 845 return: 80.0 avg return: 68.32
# epoch: 846 return: 70.0 avg return: 68.48
# epoch: 847 return: 76.0 avg return: 68.54
# epoch: 848 return: 61.0 avg return: 68.26
# epoch: 849 return: 90.0 avg return: 68.46
# epoch: 850 return: 81.0 avg return: 68.8
# epoch: 851 return: 41.0 avg return: 68.3
# epoch: 852 return: 97.0 avg return: 68.86
# epoch: 853 return: 96.0 avg return: 69.44
# epoch: 854 return: 99.0 avg return: 69.88
# epoch: 855 return: 27.0 avg return: 68.86
# epoch: 856 return: 96.0 avg return: 69.34
# epoch: 857 return: 43.0 avg return: 68.74
# epoch: 858 return: 89.0 avg return: 69.22
# epoch: 859 return: 95.0 avg return: 69.86
# epoch: 860 return: 101.0 avg return: 70.28
# epoch: 861 return: 103.0 avg return: 71.02
# epoch: 862 return: 92.0 avg return: 71.42
# epoch: 863 return: 93.0 avg return: 72.02
# epoch: 864 return: 91.0 avg return: 72.58
# epoch: 865 return: 78.0 avg return: 72.56
# epoch: 866 return: 88.0 avg return: 73.7
# epoch: 867 return: 87.0 avg return: 74.16
# epoch: 868 return: 87.0 avg return: 75.34
# epoch: 869 return: 76.0 avg return: 75.8
# epoch: 870 return: 95.0 avg return: 76.24
# epoch: 871 return: 89.0 avg return: 76.76
# epoch: 872 return: 98.0 avg return: 77.44
# epoch: 873 return: 77.0 avg return: 77.38
# epoch: 874 return: 91.0 avg return: 78.3
# epoch: 875 return: 88.0 avg return: 78.74
# epoch: 876 return: 84.0 avg return: 78.82
# epoch: 877 return: 88.0 avg return: 79.12
# epoch: 878 return: 80.0 avg return: 79.74
# epoch: 879 return: 91.0 avg return: 80.58
# epoch: 880 return: 90.0 avg return: 80.74
# epoch: 881 return: 81.0 avg return: 80.98
# epoch: 882 return: 98.0 avg return: 81.58
# epoch: 883 return: 90.0 avg return: 81.96
# epoch: 884 return: 102.0 avg return: 82.58
# epoch: 885 return: 114.0 avg return: 84.28
# epoch: 886 return: 102.0 avg return: 84.86
# epoch: 887 return: 113.0 avg return: 85.34
# epoch: 888 return: 127.0 avg return: 86.12
# epoch: 889 return: 100.0 avg return: 86.26
# epoch: 890 return: 125.0 avg return: 87.16
# epoch: 891 return: 117.0 avg return: 87.74
# epoch: 892 return: 125.0 avg return: 88.64
# epoch: 893 return: 129.0 avg return: 89.48
# epoch: 894 return: 143.0 avg return: 91.48
# epoch: 895 return: 115.0 avg return: 92.18
# epoch: 896 return: 150.0 avg return: 93.78
# epoch: 897 return: 138.0 avg return: 95.02
# epoch: 898 return: 152.0 avg return: 96.84
# epoch: 899 return: 181.0 avg return: 98.66
# epoch: 900 return: 157.0 avg return: 100.18
# epoch: 901 return: 190.0 avg return: 103.16
# epoch: 902 return: 181.0 avg return: 104.84
# epoch: 903 return: 221.0 avg return: 107.34
# epoch: 904 return: 286.0 avg return: 111.08
# epoch: 905 return: 546.0 avg return: 121.46
# epoch: 906 return: 393.0 avg return: 127.4
# epoch: 907 return: 1000.0 avg return: 146.54
# epoch: 908 return: 1000.0 avg return: 164.76
# epoch: 909 return: 1000.0 avg return: 182.86
# epoch: 910 return: 1000.0 avg return: 200.84
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-17ef5cfcac9f> in <module>
#     144                   policy_network_generator=partial(create_policy_network, state_dim=env.observation_space.shape[0],
#     145                                                    action_dim=env.action_space.shape[0]))
# --> 146     agent.train(50000)
#
# <ipython-input-14-17ef5cfcac9f> in train(self, epochs)
#     121             rets.append(ret)
#     122             print("epoch:", e, "return:", ret, "avg return:", np.average(rets[-50:]))
# --> 123             episode = buffer.get_as_data_set()
#     124             self.learn(episode)
#     125         print("training finished!")
#
# <ipython-input-14-17ef5cfcac9f> in get_as_data_set(self, batch_size)
#      23             gamma_t = 1
#      24             for k in range(t, len(self.reward_memory)):
# ---> 25                 g_sum += self.reward_memory[k] * gamma_t  # r_n[k].numpy()
#      26                 gamma_t *= self._gamma
#      27             g[t] = g_sum
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/math_ops.py in binary_op_wrapper(x, y)
#    1404         #   r_binary_op_wrapper use different force_same_dtype values.
#    1405         x, y = maybe_promote_tensors(x, y)
# -> 1406         return func(x, y, name=name)
#    1407       except (TypeError, ValueError) as e:
#    1408         # Even if dispatching the op failed, the RHS may be a tensor aware
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1074         if iterable_params is not None:
#    1075           args, kwargs = replace_iterable_params(args, kwargs, iterable_params)
# -> 1076         result = api_dispatcher.Dispatch(args, kwargs)
#    1077         if result is not NotImplemented:
#    1078           return result
#
# KeyboardInterrupt:
